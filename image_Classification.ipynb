# %% [markdown]
# <a href="https://colab.research.google.com/github/ibad321/image-_Classification/blob/main/image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Classification Ciffar10 Dataset | Multiple Image Classification CNN | ANN CIFFAR10
#
# In this project, you’ll create an image classification system that can determine the image’s class. Because image classification is such an important application in the field of deep learning, working on this project will allow you to learn about a variety of deep learning topics.
#
# Working on image categorization is one of the finest ways to get started with hands-on deep learning projects for students. CIFAR-10 is a big dataset including approximately 60,000 color images (3232 sizes) divided into ten classes, each with 6,000 images. There are 50,000 photos in the training set and 10,000 images in the test set. The training set will be divided into five portions, each containing 10,000 photos that will be organized in random order. The test set will consist of 1000 photos selected at random from each of the ten classes.

# %% [markdown]
# # Import Tools

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation,MaxPool2D,Flatten
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D,BatchNormalization
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# # Setting Constant

# %%
batch_size = 32
num_classes = 10
data_augmentation = True

# %% [markdown]
# # The data, shuffled and split between train and test sets:

# %%
# The data, shuffled and split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# # Showing Images

# %%
import matplotlib.pyplot as plt

# Create a figure and axes with the specified number of rows and columns
fig, axes = plt.subplots(2, 3, figsize=(15, 6))

# Flatten the axes array to easily iterate over subplots
axes = axes.flatten()

# Loop through the first ten images in the dataset and plot them
for i in range(2 * 3):
    # Plot the image
    axes[i].imshow(x_train[i])
    axes[i].axis('off')  # Turn off axis labels
    axes[i].set_title(f"Class: {y_train[i]}")

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature Scalling

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %% [markdown]
# # Model Architecture

# %%
INPUT_SHAPE = (32, 32, 3)
KERNEL_SIZE = (3, 3)
model = Sequential()

# Convolutional Layer
model.add(Conv2D(filters=32, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(filters=32, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(BatchNormalization())
# Pooling layer
model.add(MaxPool2D(pool_size=(2, 2)))
# Dropout layers
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters=128, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
# model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(10, activation='softmax'))



# Fully connected layer with number of units equal to the number of classes
model.add(Dense(num_classes))
# Softmax activation function for multi-class classification
model.add(Activation('softmax'))

# Print the model summary
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 32, 32, 32)        896
#
#  batch_normalization_20 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  conv2d_21 (Conv2D)          (None, 32, 32, 32)        9248
#
#  batch_normalization_21 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  max_pooling2d_9 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_22 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_22 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  conv2d_23 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_23 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  max_pooling2d_10 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_12 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_24 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_24 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  conv2d_25 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_25 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  max_pooling2d_11 (MaxPooli  (None, 4, 4, 128)         0
#  ng2D)
#
#  dropout_13 (Dropout)        (None, 4, 4, 128)         0
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 128)               262272
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  dense_5 (Dense)             (None, 10)                1290
#
#  dense_6 (Dense)             (None, 10)                110
#
#  activation (Activation)     (None, 10)                0
#
# =================================================================
# Total params: 552472 (2.11 MB)
# Trainable params: 551576 (2.10 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %% [markdown]
# # Model Compilation & Training

# %%
opt = keras.optimizers.Adamax(lr=0.001)
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adamax.

# %%
history =model.fit(x_train, y_train,
              batch_size=500,
              epochs=100,
              validation_data=(x_test, y_test),
              shuffle=True)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 18s 79ms/step - loss: 2.1461 - accuracy: 0.2090 - val_loss: 2.3479 - val_accuracy: 0.1000
# Epoch 2/100
# 100/100 [==============================] - 7s 71ms/step - loss: 2.0765 - accuracy: 0.2567 - val_loss: 2.2861 - val_accuracy: 0.1383
# Epoch 3/100
# 100/100 [==============================] - 7s 71ms/step - loss: 2.0342 - accuracy: 0.2773 - val_loss: 2.3026 - val_accuracy: 0.1187
# Epoch 4/100
# 100/100 [==============================] - 7s 71ms/step - loss: 1.9896 - accuracy: 0.2958 - val_loss: 2.1508 - val_accuracy: 0.1854
# Epoch 5/100
# 100/100 [==============================] - 7s 72ms/step - loss: 1.9493 - accuracy: 0.3257 - val_loss: 2.0154 - val_accuracy: 0.2676
# Epoch 6/100
# 100/100 [==============================] - 7s 71ms/step - loss: 1.9064 - accuracy: 0.3481 - val_loss: 1.9027 - val_accuracy: 0.3666
# Epoch 7/100
# 100/100 [==============================] - 7s 71ms/step - loss: 1.8645 - accuracy: 0.3678 - val_loss: 1.8574 - val_accuracy: 0.3868
# Epoch 8/100
# 100/100 [==============================] - 7s 73ms/step - loss: 1.8167 - accuracy: 0.3918 - val_loss: 1.8162 - val_accuracy: 0.3721
# Epoch 9/100
# 100/100 [==============================] - 7s 71ms/step - loss: 1.7738 - accuracy: 0.4041 - val_loss: 1.7602 - val_accuracy: 0.4030
# Epoch 10/100
# 100/100 [==============================] - 7s 73ms/step - loss: 1.7297 - accuracy: 0.4248 - val_loss: 1.7372 - val_accuracy: 0.4142
# Epoch 11/100
# 100/100 [==============================] - 7s 72ms/step - loss: 1.6830 - accuracy: 0.4490 - val_loss: 1.6983 - val_accuracy: 0.4203
# Epoch 12/100
# 100/100 [==============================] - 7s 74ms/step - loss: 1.6401 - accuracy: 0.4670 - val_loss: 1.6278 - val_accuracy: 0.4634
# Epoch 13/100
# 100/100 [==============================] - 7s 74ms/step - loss: 1.5971 - accuracy: 0.4883 - val_loss: 1.5885 - val_accuracy: 0.4833
# Epoch 14/100
# 100/100 [==============================] - 7s 73ms/step - loss: 1.5534 - accuracy: 0.5030 - val_loss: 1.5544 - val_accuracy: 0.4913
# Epoch 15/100
# 100/100 [==============================] - 7s 73ms/step - loss: 1.5091 - accuracy: 0.5166 - val_loss: 1.5306 - val_accuracy: 0.4899
# Epoch 16/100
# 100/100 [==============================] - 7s 73ms/step - loss: 1.4692 - accuracy: 0.5243 - val_loss: 1.4878 - val_accuracy: 0.5078
# Epoch 17/100
# 100/100 [==============================] - 7s 74ms/step - loss: 1.4287 - accuracy: 0.5353 - val_loss: 1.4405 - val_accuracy: 0.5138
# Epoch 18/100
# 100/100 [==============================] - 7s 74ms/step - loss: 1.3840 - accuracy: 0.5446 - val_loss: 1.4550 - val_accuracy: 0.5098
# Epoch 19/100
# 100/100 [==============================] - 7s 73ms/step - loss: 1.3487 - accuracy: 0.5509 - val_loss: 1.3871 - val_accuracy: 0.5210
# Epoch 20/100
# 100/100 [==============================] - 7s 74ms/step - loss: 1.3100 - accuracy: 0.5622 - val_loss: 1.3286 - val_accuracy: 0.5450
# Epoch 21/100
# 100/100 [==============================] - 7s 73ms/step - loss: 1.2743 - accuracy: 0.5669 - val_loss: 1.2993 - val_accuracy: 0.5473
# Epoch 22/100
# 100/100 [==============================] - 7s 74ms/step - loss: 1.2402 - accuracy: 0.5758 - val_loss: 1.3027 - val_accuracy: 0.5484
# Epoch 23/100
# 100/100 [==============================] - 7s 73ms/step - loss: 1.2091 - accuracy: 0.5810 - val_loss: 1.2385 - val_accuracy: 0.5579
# Epoch 24/100
# 100/100 [==============================] - 7s 73ms/step - loss: 1.1784 - accuracy: 0.5891 - val_loss: 1.2206 - val_accuracy: 0.5732
# Epoch 25/100
# 100/100 [==============================] - 7s 74ms/step - loss: 1.1505 - accuracy: 0.5962 - val_loss: 1.2175 - val_accuracy: 0.5632
# Epoch 26/100
# 100/100 [==============================] - 7s 73ms/step - loss: 1.1219 - accuracy: 0.6024 - val_loss: 1.1930 - val_accuracy: 0.5717
# Epoch 27/100
# 100/100 [==============================] - 7s 73ms/step - loss: 1.0990 - accuracy: 0.6073 - val_loss: 1.1553 - val_accuracy: 0.5883
# Epoch 28/100
# 100/100 [==============================] - 7s 73ms/step - loss: 1.0762 - accuracy: 0.6129 - val_loss: 1.1192 - val_accuracy: 0.5916
# Epoch 29/100
# 100/100 [==============================] - 7s 73ms/step - loss: 1.0551 - accuracy: 0.6202 - val_loss: 1.1132 - val_accuracy: 0.5896
# Epoch 30/100
# 100/100 [==============================] - 7s 73ms/step - loss: 1.0348 - accuracy: 0.6256 - val_loss: 1.1041 - val_accuracy: 0.5985
# Epoch 31/100
# 100/100 [==============================] - 7s 73ms/step - loss: 1.0139 - accuracy: 0.6301 - val_loss: 1.0843 - val_accuracy: 0.6032
# Epoch 32/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.9963 - accuracy: 0.6345 - val_loss: 1.0723 - val_accuracy: 0.6050
# Epoch 33/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.9769 - accuracy: 0.6415 - val_loss: 1.0537 - val_accuracy: 0.6123
# Epoch 34/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.9562 - accuracy: 0.6502 - val_loss: 1.0534 - val_accuracy: 0.6090
# Epoch 35/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.9416 - accuracy: 0.6524 - val_loss: 1.0336 - val_accuracy: 0.6116
# Epoch 36/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.9309 - accuracy: 0.6600 - val_loss: 1.0209 - val_accuracy: 0.6220
# Epoch 37/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.9120 - accuracy: 0.6686 - val_loss: 1.0013 - val_accuracy: 0.6203
# Epoch 38/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.9009 - accuracy: 0.6717 - val_loss: 1.0391 - val_accuracy: 0.6242
# Epoch 39/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.8864 - accuracy: 0.6822 - val_loss: 1.0037 - val_accuracy: 0.6556
# Epoch 40/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.8748 - accuracy: 0.6937 - val_loss: 1.0038 - val_accuracy: 0.6578
# Epoch 41/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.8600 - accuracy: 0.7051 - val_loss: 1.0271 - val_accuracy: 0.6419
# Epoch 42/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.8480 - accuracy: 0.7153 - val_loss: 0.9803 - val_accuracy: 0.6826
# Epoch 43/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.8346 - accuracy: 0.7253 - val_loss: 0.9608 - val_accuracy: 0.6896
# Epoch 44/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.8198 - accuracy: 0.7368 - val_loss: 0.9445 - val_accuracy: 0.7045
# Epoch 45/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.8061 - accuracy: 0.7443 - val_loss: 0.9285 - val_accuracy: 0.7096
# Epoch 46/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.7935 - accuracy: 0.7526 - val_loss: 0.9095 - val_accuracy: 0.7242
# Epoch 47/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.7800 - accuracy: 0.7598 - val_loss: 0.9360 - val_accuracy: 0.7240
# Epoch 48/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.7693 - accuracy: 0.7668 - val_loss: 0.9073 - val_accuracy: 0.7340
# Epoch 49/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.7528 - accuracy: 0.7736 - val_loss: 0.9168 - val_accuracy: 0.7325
# Epoch 50/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.7416 - accuracy: 0.7800 - val_loss: 0.8800 - val_accuracy: 0.7449
# Epoch 51/100
# 100/100 [==============================] - 8s 77ms/step - loss: 0.7322 - accuracy: 0.7836 - val_loss: 0.9055 - val_accuracy: 0.7329
# Epoch 52/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.7164 - accuracy: 0.7888 - val_loss: 0.9056 - val_accuracy: 0.7396
# Epoch 53/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.7022 - accuracy: 0.7941 - val_loss: 0.8738 - val_accuracy: 0.7506
# Epoch 54/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.6943 - accuracy: 0.7982 - val_loss: 0.8657 - val_accuracy: 0.7510
# Epoch 55/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.6842 - accuracy: 0.7999 - val_loss: 0.8741 - val_accuracy: 0.7472
# Epoch 56/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.6692 - accuracy: 0.8057 - val_loss: 0.8376 - val_accuracy: 0.7535
# Epoch 57/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.6597 - accuracy: 0.8075 - val_loss: 0.8419 - val_accuracy: 0.7590
# Epoch 58/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.6496 - accuracy: 0.8081 - val_loss: 0.8265 - val_accuracy: 0.7575
# Epoch 59/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.6396 - accuracy: 0.8122 - val_loss: 0.8254 - val_accuracy: 0.7606
# Epoch 60/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.6324 - accuracy: 0.8132 - val_loss: 0.8234 - val_accuracy: 0.7608
# Epoch 61/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.6202 - accuracy: 0.8184 - val_loss: 0.8375 - val_accuracy: 0.7630
# Epoch 62/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.6111 - accuracy: 0.8205 - val_loss: 0.8032 - val_accuracy: 0.7649
# Epoch 63/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.6020 - accuracy: 0.8214 - val_loss: 0.8085 - val_accuracy: 0.7685
# Epoch 64/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.5949 - accuracy: 0.8232 - val_loss: 0.8044 - val_accuracy: 0.7703
# Epoch 65/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.5889 - accuracy: 0.8257 - val_loss: 0.8315 - val_accuracy: 0.7624
# Epoch 66/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.5785 - accuracy: 0.8256 - val_loss: 0.7787 - val_accuracy: 0.7721
# Epoch 67/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.5725 - accuracy: 0.8293 - val_loss: 0.7868 - val_accuracy: 0.7698
# Epoch 68/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.5636 - accuracy: 0.8305 - val_loss: 0.7750 - val_accuracy: 0.7738
# Epoch 69/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.5539 - accuracy: 0.8340 - val_loss: 0.7726 - val_accuracy: 0.7772
# Epoch 70/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.5474 - accuracy: 0.8350 - val_loss: 0.7802 - val_accuracy: 0.7775
# Epoch 71/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.5374 - accuracy: 0.8388 - val_loss: 0.7736 - val_accuracy: 0.7723
# Epoch 72/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.5338 - accuracy: 0.8377 - val_loss: 0.7632 - val_accuracy: 0.7734
# Epoch 73/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.5290 - accuracy: 0.8395 - val_loss: 0.7623 - val_accuracy: 0.7802
# Epoch 74/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.5171 - accuracy: 0.8426 - val_loss: 0.7624 - val_accuracy: 0.7793
# Epoch 75/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.5135 - accuracy: 0.8433 - val_loss: 0.7872 - val_accuracy: 0.7671
# Epoch 76/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.5096 - accuracy: 0.8433 - val_loss: 0.7713 - val_accuracy: 0.7746
# Epoch 77/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4989 - accuracy: 0.8459 - val_loss: 0.7527 - val_accuracy: 0.7785
# Epoch 78/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4951 - accuracy: 0.8481 - val_loss: 0.7422 - val_accuracy: 0.7819
# Epoch 79/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.4880 - accuracy: 0.8482 - val_loss: 0.7417 - val_accuracy: 0.7740
# Epoch 80/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4838 - accuracy: 0.8489 - val_loss: 0.7328 - val_accuracy: 0.7841
# Epoch 81/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.4778 - accuracy: 0.8497 - val_loss: 0.7268 - val_accuracy: 0.7860
# Epoch 82/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.4714 - accuracy: 0.8515 - val_loss: 0.7256 - val_accuracy: 0.7851
# Epoch 83/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.4676 - accuracy: 0.8536 - val_loss: 0.7350 - val_accuracy: 0.7875
# Epoch 84/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.4601 - accuracy: 0.8539 - val_loss: 0.7403 - val_accuracy: 0.7808
# Epoch 85/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4592 - accuracy: 0.8537 - val_loss: 0.7300 - val_accuracy: 0.7820
# Epoch 86/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4548 - accuracy: 0.8559 - val_loss: 0.7351 - val_accuracy: 0.7844
# Epoch 87/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4451 - accuracy: 0.8581 - val_loss: 0.7293 - val_accuracy: 0.7827
# Epoch 88/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4395 - accuracy: 0.8595 - val_loss: 0.7355 - val_accuracy: 0.7793
# Epoch 89/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4400 - accuracy: 0.8608 - val_loss: 0.7191 - val_accuracy: 0.7882
# Epoch 90/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.4345 - accuracy: 0.8611 - val_loss: 0.7071 - val_accuracy: 0.7896
# Epoch 91/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4315 - accuracy: 0.8611 - val_loss: 0.7444 - val_accuracy: 0.7785
# Epoch 92/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4269 - accuracy: 0.8603 - val_loss: 0.7491 - val_accuracy: 0.7826
# Epoch 93/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.4208 - accuracy: 0.8644 - val_loss: 0.7286 - val_accuracy: 0.7823
# Epoch 94/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4140 - accuracy: 0.8666 - val_loss: 0.7344 - val_accuracy: 0.7843
# Epoch 95/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.4170 - accuracy: 0.8648 - val_loss: 0.7143 - val_accuracy: 0.7837
# Epoch 96/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.4093 - accuracy: 0.8673 - val_loss: 0.6992 - val_accuracy: 0.7892
# Epoch 97/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.4059 - accuracy: 0.8702 - val_loss: 0.7484 - val_accuracy: 0.7817
# Epoch 98/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.4028 - accuracy: 0.8680 - val_loss: 0.6965 - val_accuracy: 0.7933
# Epoch 99/100
# 100/100 [==============================] - 7s 74ms/step - loss: 0.3972 - accuracy: 0.8709 - val_loss: 0.7261 - val_accuracy: 0.7902
# Epoch 100/100
# 100/100 [==============================] - 7s 73ms/step - loss: 0.3971 - accuracy: 0.8703 - val_loss: 0.6972 - val_accuracy: 0.7900

# %% [markdown]
# # Save the Model

# %%
model.save("cifar10_model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Training and Validation Loss

# %%
import seaborn as sb
plt.figure(figsize=(10,6))
sb.set_style("whitegrid")
plt.plot(history.history['accuracy'],color="#E74C3C",marker='o')
plt.plot(history.history['val_accuracy'],color='#641E16',marker='h')
plt.title('Accuracy comparison between Validation and Train Data set',fontsize=15)
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
plt.figure(figsize=(10,6))
sb.set_style("whitegrid")
plt.plot(history.history['loss'],color="#E74C3C",marker='o')
plt.plot(history.history['val_loss'],color='#641E16',marker='h')
plt.title('Loss comparison between Validation and Train Data set',fontsize=15)
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
#predictions on the test data and store them in y_pred
y_pred = model.predict(x_test)
# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 313/313 [==============================] - 2s 4ms/step

# %% [markdown]
# # Classification Report

# %%
# Generate the classification report
from sklearn.metrics import classification_report

class_report = classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1))

# Print the classification report
print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85      1000
#            1       0.94      0.89      0.91      1000
#            2       0.72      0.74      0.73      1000
#            3       0.52      0.34      0.41      1000
#            4       0.74      0.83      0.78      1000
#            5       0.57      0.72      0.64      1000
#            6       0.82      0.89      0.86      1000
#            7       0.93      0.84      0.88      1000
#            8       0.92      0.90      0.91      1000
#            9       0.87      0.91      0.89      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.79      0.79      0.79     10000
# weighted avg       0.79      0.79      0.79     10000

# %% [markdown]
# # Predictive System

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

def predict():
    # Randomly select an index from the test set
    idx = random.randint(0, len(x_test) - 1)

    # Select the image and its corresponding label
    image = x_test[idx]
    actual_label = y_test[idx]

    # Make predictions using the trained model
    predictions = model.predict(np.expand_dims(image, axis=0))
    predicted_label = np.argmax(predictions)

    # Define class names (assuming num_classes is defined)
    class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
                  'dog', 'frog', 'horse', 'ship', 'truck']


    # Display the image
    plt.figure(figsize=(1,1))
    plt.imshow(image)
    plt.axis('off')
    plt.title(f'Actual: {class_names[np.argmax(actual_label)]}, Predicted: {class_names[predicted_label]}')
    plt.show()

# %%
predict()
# Out:
# 1/1 [==============================] - 0s 374ms/step

# %%
predict()
# Out:
# 1/1 [==============================] - 0s 19ms/step
